# %%
import pandas as pd

#%% 
df = pd.read_csv('crimes_asa_sul_2020_2025_com_pessoas_endereco.csv')
df.head(100)
# Out:
#      latitude  longitude        data   hora  tipo_crime   bairro      rua  \
# 0  -15.792515 -47.882197  2022-02-19  22:15  vandalismo  Asa Sul  SQS 105
# 1  -15.797208 -47.879688  2020-08-12  19:30       furto  Asa Sul  CLS 402
# 2  -15.789538 -47.883429  2025-11-02  04:43     tráfico  Asa Sul  SQS 106
# 3  -15.786870 -47.888272  2020-05-17  18:57  vandalismo  Asa Sul  SQS 108
# 4  -15.794049 -47.881769  2023-06-12  11:09       roubo  Asa Sul  CLS 401
# ..        ...        ...         ...    ...         ...      ...      ...
# 95 -15.794860 -47.877211  2021-05-26  19:55  vandalismo  Asa Sul  CLS 401
# 96 -15.792723 -47.883994  2022-01-19    NaN       furto  Asa Sul  SQS 106
# 97 -15.788096 -47.888009  2021-02-28  23:28       furto  Asa Sul  SQS 108
# 98 -15.797740 -47.882875  2024-07-26  19:00       roubo  Asa Sul   W3 Sul
# 99 -15.797314 -47.881862  2024-09-20    NaN       roubo  Asa Sul  CLS 401
#
#         tipo_dia   ano                     nome             cpf  idade  \
# ...
